# %%
# Install selenium
#!pip install selenium
# Out:
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
# Requirement already satisfied: urllib3 in c:\users\denni\anaconda3\lib\site-packages (from selenium) (1.25.7)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
# Collecting parsel
#   Downloading https://files.pythonhosted.org/packages/23/1e/9b39d64cbab79d4362cdd7be7f5e9623d45c4a53b3f7522cd8210df52d8e/parsel-1.6.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.6.0 in c:\users\denni\anaconda3\lib\site-packages (from parsel) (1.13.0)
# Requirement already satisfied: lxml in c:\users\denni\anaconda3\lib\site-packages (from parsel) (4.4.2)
# Collecting w3lib>=1.19.0
#   Downloading https://files.pythonhosted.org/packages/a3/59/b6b14521090e7f42669cafdb84b0ab89301a42f1f1a82fcf5856661ea3a7/w3lib-1.22.0-py2.py3-none-any.whl
# Collecting cssselect>=0.9
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Installing collected packages: w3lib, cssselect, parsel
# Successfully installed cssselect-1.1.0 parsel-1.6.0 w3lib-1.22.0

# %%
# Import statements
from selenium import webdriver
import pandas as pd

# %%
# Initialize the webdriver and specify browser
driver = webdriver.Chrome()
driver.get("https://fintechcanada.io/explore/?pg=1&country%5B%5D=Canada&sort=a-z")

# %%
# Empty list to store company names
coNames = []

# counter var
j = 1

# While count is less than or equal to 47 (number of pages)
while (j <= 47):
    
    # Visit every page
    url = "https://fintechcanada.io/explore/?pg={}&country%5B%5D=Canada&sort=a-z".format(j)
    driver.get(url)
    
    # Find the company name
    coNames_element = driver.find_elements_by_xpath("//*[@class='case27-secondary-text listing-preview-title']")
    
    # Add it to the list of company names
    for i in range(len(coNames_element)):
        coNames.append(coNames_element[i].text)
    
    # Increment the counter
    j = j+1

# Print list of company names
print(coNames)
# Out:
# ['Accesswire', 'Consilium Crypto Inc', 'Exponential', 'FrontFundr', 'FundRazr', 'Holt Accelerator', 'KABN Systems North America Inc.', 'KOHO Financial', 'Ledn', 'Lending Loop', 'National Crowdfunding & Fintech Association (NCFA)', 'Next Decentrum', 'Remilard Consulting Group', 'Trade Commissioner Service', 'Venture Law Corp', 'Wealthsimple', '1Kosmos INC.', '21MIL', '360 Cloud Accounting', '365 Invoicing', '3commas', '3iQ Corp', '4PAY', 'A1 Payroll', 'AAIR.AI', 'Abelian Tech', 'Absolute', 'Accept Local', 'Acceptiv', 'Accufile', 'ACE Money Transfer', 'Acomba', 'Actuarial Perspective', 'Advataxes', 'Adventu Financial Technologies', 'Agility Forex', 'Agreement Express', 'AgriLogicAI', 'Aha Insurance', 'AIBB Inc.', 'Aidvisors', 'Aion', 'AJS Canada', 'Alaunus', 'Alessa, CaseWare RCM', 'AlgoTrades', 'Alkemi AI Inc.', 'ALKYD Inc.', 'All Savings Trading', 'Allai', 'Allcoin', 'Allegory Technology Inc', 'Alligato', 'Allset', 'Aloha', 'AlphaDesk', 'Alt 5 Sigma', 'Alterna Savings and Credit Union Ltd.', 'Amber Financial', 'Ambo Technologies', 'Ameis Regulatory Services', 'Amilia Enterprises Inc.', 'Ampli', 'Amplify', 'Analyze Re', 'Anevis solutions', 'Angoss Software Corporation', 'Anywhere Commerce', 'Aone Financial', 'APEXA', 'Apifini', 'Applied Telemetrics (Paybysky)', 'Approval Genie', 'APrivacy Pte. Ltd', 'Aquantix', 'Aquilon', 'Ark Paradigm', 'ArtsFunding', 'Artventure', 'Aspire Accounting Services', 'Asset Direct of Canada Inc.', 'ATB Financial dBa ATB BoostR', 'Aubea', 'AutoloansForEveryDriver', 'Auvenir', 'Avantage', 'Avantshire', 'Axepay', 'AxesNetwork', 'Aya Payments', 'Ayuda Pay', 'AZUR Group', 'B2Billing Payments', 'Back in Black', 'BackerCity', 'Bacon Financial Technologies Inc', 'Balance', 'Bambora', 'BankMine', 'Bare Team', 'Base Portfolio', 'Baseline Telematics', 'Baystream Corporation', 'BDC IT Venture Fund', 'Bean Cruncher Software Inc', 'Beanworks', 'Bench', 'Berkeley Payment', 'Berman Sarrazin', 'Besure', 'Better Capital', 'Betterworth', 'Big Terminal', 'BioConnect', 'Bitaccess', 'Bitbuy', 'Bitcoin Solutions', 'Bitcoiniancs', 'BitGold', 'Bitnational Inc.', 'BitRush Corp', 'bkXchange', 'Blanc Labs (Blanclink Inc.)', 'Blink Mortgage', 'BlockAble Inc.', 'BlockCAT Technologies', 'BlockEquity Inc. (Coinsquare)', 'Blockfusion', 'Blockstation', 'Blockstream', 'BlockX Labs', 'BlocPal International Inc.', 'BlueRush', 'Borrowell', 'Breathe Life', 'BrightQuadrant Corporation', 'Brightspark Financial', 'Brim Financial Inc.', 'Brix', 'Brokercore', 'BrokerLift', 'Buckzy', 'Budget Express', 'Budgeto', 'Bullfrog Insurance', 'Butler Mortgage', 'Buy Bitcoin Worldwide', 'Bylls', 'Caledon', 'CalendarBudget', 'Cambridge Global Payments', 'Camilion', 'Canada Drives', 'Canada Mobile Payments', 'Canadian Bitcoins', 'Canadian Bullion Services Inc.', 'Canadian Mortgage App', 'Canadian Wealth', 'Canalyst', 'CanDeal', 'Canpay', 'Capiche', 'Capital Blockchain', 'Car Loans 411', 'Carebook', 'CarLoanStudent', 'CARPROOF Corporation (Carfax)', 'Carta Worldwide', 'CaseWare International', 'Cash 4 You Corp.', 'Cash Passport', 'Cashflow.io', 'CashPoint', 'Cassia Research (Copilot)', 'Castle Hall Alternatives, Inc.', 'Causeview Inc.', 'CaVirtex', 'CBV Collection Services', 'Celero Solutions', 'Centigram', 'Central Technology Services Corporation', 'Certn Holdings Inc.', 'ChangeJar', 'ChargeNational', 'Charity Can (Third sector publishing)', 'Chart Mogul', 'ChartSmart', 'Checkfront', 'Chimp (Charitable Impact)', 'Chisel AI', 'CIMPL Inc.', 'Cinchy', 'Citizen Hex', 'Claim Control', 'ClaimCast', 'ClaimsPro (scm)', 'Clarity Payment', 'Clear Biz', 'Clear View KYC', 'Clearbanc', 'ClearRisk', 'Click Capital', 'Click Payments Inc.', 'Client Track', 'ClientDesk', 'Clientelligent', 'Clik.ai', 'Co-Power', 'Cognera Corporation', 'Coinbask', 'Coinberry', 'Coinbio', 'Coinchange Financials Inc.', 'Coinfield', 'Coinkite', 'CoinPayments', 'CoinQX', 'CoinsBill', 'CoinSmart', 'Coinsquare', 'Collage', 'Comflo', 'Commercial Passport KYC', 'Company Capital', 'Company Capital S ...

# %%
# Empty list to store modified company names for url
co = []

# For each company name, change it to lower case (if has " &", delete it), replace space chars with "-"
for i in range(len(coNames)):
    co.append(coNames[i].lower().replace(" &", "").replace(" ", "-"))
    print(co[i])
# Out:
# accesswire
# consilium-crypto-inc
# exponential
# frontfundr
# fundrazr
# holt-accelerator
# kabn-systems-north-america-inc.
# koho-financial
# ledn
# lending-loop
# national-crowdfunding-fintech-association-(ncfa)
# next-decentrum
# remilard-consulting-group
# trade-commissioner-service
# venture-law-corp
# wealthsimple
# 1kosmos-inc.
# 21mil
# 360-cloud-accounting
# 365-invoicing
# 3commas
# 3iq-corp
# 4pay
# a1-payroll
# aair.ai
# abelian-tech
# absolute
# accept-local
# acceptiv
# accufile
# ace-money-transfer
# acomba
# actuarial-perspective
# advataxes
# adventu-financial-technologies
# agility-forex
# agreement-express
# agrilogicai
# aha-insurance
# aibb-inc.
# aidvisors
# aion
# ajs-canada
# alaunus
# alessa,-caseware-rcm
# algotrades
# alkemi-ai-inc.
# alkyd-inc.
# all-savings-trading
# allai
# allcoin
# allegory-technology-inc
# alligato
# allset
# aloha
# alphadesk
# alt-5-sigma
# alterna-savings-and-credit-union-ltd.
# amber-financial
# ambo-technologies
# ameis-regulatory-services
# amilia-enterprises-inc.
# ampli
# amplify
# analyze-re
# anevis-solutions
# angoss-software-corporation
# anywhere-commerce
# aone-financial
# apexa
# apifini
# applied-telemetrics-(paybysky)
# approval-genie
# aprivacy-pte.-ltd
# aquantix
# aquilon
# ark-paradigm
# artsfunding
# artventure
# aspire-accounting-services
# asset-direct-of-canada-inc.
# atb-financial-dba-atb-boostr
# aubea
# autoloansforeverydriver
# auvenir
# avantage
# avantshire
# axepay
# axesnetwork
# aya-payments
# ayuda-pay
# azur-group
# b2billing-payments
# back-in-black
# backercity
# bacon-financial-technologies-inc
# balance
# bambora
# bankmine
# bare-team
# base-portfolio
# baseline-telematics
# baystream-corporation
# bdc-it-venture-fund
# bean-cruncher-software-inc
# beanworks
# bench
# berkeley-payment
# berman-sarrazin
# besure
# better-capital
# betterworth
# big-terminal
# bioconnect
# bitaccess
# bitbuy
# bitcoin-solutions
# bitcoiniancs
# bitgold
# bitnational-inc.
# bitrush-corp
# bkxchange
# blanc-labs-(blanclink-inc.)
# blink-mortgage
# blockable-inc.
# blockcat-technologies
# blockequity-inc.-(coinsquare)
# blockfusion
# blockstation
# blockstream
# blockx-labs
# blocpal-international-inc.
# bluerush
# borrowell
# breathe-life
# brightquadrant-corporation
# brightspark-financial
# brim-financial-inc.
# brix
# brokercore
# brokerlift
# buckzy
# budget-express
# budgeto
# bullfrog-insurance
# butler-mortgage
# buy-bitcoin-worldwide
# bylls
# caledon
# calendarbudget
# cambridge-global-payments
# camilion
# canada-drives
# canada-mobile-payments
# canadian-bitcoins
# canadian-bullion-services-inc.
# canadian-mortgage-app
# canadian-wealth
# canalyst
# candeal
# canpay
# capiche
# capital-blockchain
# car-loans-411
# carebook
# carloanstudent
# carproof-corporation-(carfax)
# carta-worldwide
# caseware-international
# cash-4-you-corp.
# cash-passport
# cashflow.io
# cashpoint
# cassia-research-(copilot)
# castle-hall-alternatives,-inc.
# causeview-inc.
# cavirtex
# cbv-collection-services
# celero-solutions
# centigram
# central-technology-services-corporation
# certn-holdings-inc.
# changejar
# chargenational
# charity-can-(third-sector-publishing)
# chart-mogul
# chartsmart
# checkfront
# chimp-(charitable-impact)
# chisel-ai
# cimpl-inc.
# cinchy
# citizen-hex
# claim-control
# claimcast
# claimspro-(scm)
# clarity-payment
# clear-biz
# clear-view-kyc
# clearbanc
# clearrisk
# click-capital
# click-payments-inc.
# client-track
# clientdesk
# clientelligent
# clik.ai
# co-power
# cognera-corporation
# coinbask
# coinberry
# coinbio
# coinchange-financials-inc.
# coinfield
# coinkite
# coinpayments
# coinqx
# coinsbill
# coinsmart
# coinsquare
# collage
# comflo
# commercial-passport-kyc
# company-capital
# company-capital-small-business-loans
# comparemyrates
# conconi-growth-partners
# conexiom
# connectionpoint-systems-inc.
# considerfunding.com
# copperleaf-technologies-inc.
# corl-financial-technologies
# cortland-credit-group
# cosigned
# cosquare-inc.
# covarity
# covera
# crater-labs
# credit-club
# credit-karma-canada
# creditaid
# creditgenie
# creditron
# croeusus
# crosshair-rms
# crowd-amplify
# crowdfund-suite
# crowdmatrix
# cryptiv
# crypto-terminal
# cryptocanucks-inc.
# cryptokitties
# cryptonite
# cto-boost-inc.
# curexe
# d1g1t-inc.
# d2r-collect
# darkhorse-analytics-inc.
# data-performers
# dcr-strategies
# de-thomas-wealth-management
# dealnet-capital-corp.
# dealpoint
# decentral-dba-jaxx
# delego
# delta-360
# delve-labs
# denilson
# derivative-valuation-services
# dessa
# devlos-software-inc.
# diginomics
# digital-retail-apps-inc.
# digital-shape-technologies
# digitech-payments
# direxyon-technologies
# distill-analytics
# distributed-id
# dmg-blockchain-solutions
# dmti-spatial
# dojo-technology-corporation
# donorhut
# donum-link
# doorr
# doorval
# dream-payments
# drop-technologies-inc.
# dryrun
# ducovest-inc.
# dwello
# dynac
# dynacom
# e-xact
# easyfinancial
# easyinsure
# eclaims-workflow
# ecloid
# eft-canada
# eidosearch
# einsteinium
# elastic-path
# elavon-(collective-pos)
# element-ai
# emma
# encircle
# encorefx
# enliven-financial
# ensea-bill
# enstream
# enter-my-invoice
# eotpro
# epic-blockchain
# eq-bank
# equifund
# equilease
# equisoft
# equity.io
# equityfeed
# equitysoft-investments-valuations
# equivesto-inc.
# esentire
# esi-payroll
# espresso-capital
# ether-capital
# etherwall
# ethoca
# ethor-inc.
# every-financial-dba-every-inc.
# evolocity-financial-group
# exagens
# exchange-bank-of-canada
# exempt-edge
# exia-inc-(solutions-exia-inc)
# expensepoint
# expertus
# extreme-venture-partners
# ez-track-expense
# ez-tfa
# ezbooks
# fairom-inc.
# fast-access-financial
# fast-capital-loan
# fazezero
# federated-payments
# fentury
# ferst-capital-partners
# fiin-inc.
# filament-ai
# finabanx
# finaeo-inc.
# finance-toi-mieux
# financeit
# financial-management-technologies-inc.
# financialcad-corporation
# finatechal
# findynamics
# finhaven
# finlogik
# finmark-financials
# finn-ai
# finnovate.io
# finovertech
# finovo
# finstripe
# fintros-inc.
# fintrux-network
# firstontario-credit-union
# fiska-inc.
# fispan
# flare-systems
# flexfi
# flexiti-financial
# flexxus-business-solutions
# flightclaim.ca
# flinks
# flipgive
# flowtracker-analytics-inc.
# fluid-delivery-solutions,-inc.
# fluttrbox
# flux-network
# flybits
# foregrowth
# foxquilt
# foxtail-invoicing
# framework-venture-partners
# fraud-cloud
# freecarinsurancequote
# fresh-start-finance
# freshbooks
# freshvu2go
# fundever
# fundica
# fundify
# fundingnomad
# fundmetric
# fundmore.ai
# fundscraper-capital-inc
# fundthrough
# fusebill
# futurefunder.ca
# fynse
# geva-solution-inc.
# giving-gateway
# glance-technologies
# globalviewgrc
# goday
# gogo-loans
# golden-ventures
# goldmoney
# goldmoney-wealth-limited-(jersey
# goowi-inc.
# gotroo
# grain-discovery
# grandco
# grayblock-power
# great-north-capital
# greedyrates
# greenbank-capital-inc
# grow-technologies-inc.-(acquired-by-atb)
# happyaccounts-software
# hardbacon
# haricot
# hashchain
# haywood-financial-technology
# hd-invoice
# health-smart-financial-services
# healthquotes.ca
# heat-maps
# hedgewood
# hedgie
# helcim
# helium-investments
# hellosafe
# herd-label
# highline-beta
# hive-blockchain-technologies
# hiwave
# hockeystick
# hodlbot,-inc.
# homebound
# homewise
# honey-badger
# honkmobile
# horizon-studios-inc
# hostedpci
# hotspot-parking-inc
# hr-club
# hubdoc
# hubio
# hudson-hill-capital
# humi-inc.
# hut-8-mining-corp.
# huxton-black
# hydra-investments
# hyperblock
# icapital-financial-services-corp.
# icash
# icat
# icomply-investor-services-inc.
# id-verify-whiz
# id-m.me
# ignite-payments
# ignitiondeck
# imetrik
# impak-finance
# incipient-industries-inc.
# indellient
# inetco-systems-ltd.
# infin
# infinite-investment-system
# infoflo-pay
# information-venture-partners
# inovestor
# inovia-capital
# instacheques
# instacoin
# instagrad
# instant
# instant-hst
# instinctive-bi-canada
# insurance-for-children
# insurance-hero
# insurance-hunter
# insurance-jack
# insurance-systems
# insurecert
# insurecrypt
# insured-connect
# insuremy
# insureye
# insurpia
# insurr
# intact-centre
# integrate.ai
# integrated-rewards-inc.-dba-paymi
# intelfolio
# intelligent-mechatronic-systems
# interac
# interbit-(btl-group-ltd.)
# interblockchain-dba-transledger
# interchange-financial
# intuit-canada-ulc
# inveezy
# invest-local-bc
# investorcom-inc.
# investx
# invisor-financial-inc
# invoice-delivery-service
# invoice-simple
# iqmetrix
# iwave-information-systems,-inc.
# jade-software-systems
# jauntin
# jaxx-blockchain-interface-(decentral)
# jbilling
# jel-pacific-enterprises-inc.
# jlr-solutions
# joist-inc.
# judi.ai
# jumpq
# just-compare
# just-insuring
# justwealth
# kalepso
# kaloot
# kanetix-ltd.
# karma-insurance
# kashoo
# katipult-technology-corp
# keal
# kenyapesa
# kerby-reid
# keyfi
# keystone-finance-solutions
# kick-start-wealth
# kippin
# kiwili
# klipfolio
# knit-technologies
# knøx-industries
# koind
# koios-intelligence
# konnect-mobile-communications-inc.
# konneko
# kooltra
# korapay-technologies-limited
# krypto
# kubra-data-transfer-ltd.
# la-capitale
# la-ruche
# league
# ledgerdocs
# lendesk
# lendful-financial-inc
# lendified
# lendingarch
# lendingcompanion
# lendmart
# lendtech-group
# life-by-the-pie
# life-design-analysis
# lift-accounting
# lightspeed
# likalo
# liquid-crowd
# litecoin
# livsta
# loan-away
# loanconnect
# loans-canada
# loans-sos
# localcoin
# lofranco-corriero
# longview
# lowest-rates
# lowestrates.ca
# lucova
# luevo
# luge-capital
# magical-credit
# major-group-inc.
# make-giving-happen
# makeachamp
# mantle-technology-inc.
# manzil
# marbe-financial
# market-iq
# marketcetera-inc.
# markets'-compass
# mars-fintech-cluster
# mavennet
# mazooma
# media-coin
# mentio
# merang
# merchant-advance-capital
# metamesh-consulting-group
# metaverse-capital-corp
# metrics-chartered-professional-accounting
# mi-pay
# micc-financial-inc
# micharity-inc.
# micruity
# midata
# mig-insurance
# mina-ai-inc
# mindbridge-analytics-inc.
# mining-colocation
# mintgreen
# mistral-venture-partners
# mitre-media
# mlg-blockchain
# mnikolic-investment-research
# mobeewave
# mobetize
# mobilearth
# modernadvisor
# moj.io-inc.
# momenteo
# moneris
# monexa-services-inc.
# monexgroup
# moneymate
# motion-pay-technology
# motivewave
# mountx-real-estate-capital
# mrez---multifamily-real-estate-exchange
# mt>ventures
# mtfx-group
# multiview-corporation
# my-canada-payday
# my-class-needs
# my-insurance-broker
# my-mortgage-auction
# mybooks
# myevent
# mylo
# myplanmap
# nanopay
# nebula-ai
# nectr-tech
# neptune-dash
# nest-wealth
# nestready
# netcoins
# netdollar
# netsurance
# newbridge-advantage
# newton
# nexonia-technologies-inc.
# nextax
# nexuscrowd
# ngrain
# nickler
# nickler
# niko-/-nikola-tesla-unite
# nobul-corporation
# north-side
# northern-block
# northone
# nuco
# nuera-insurance
# nukern
# nuvei-technologies
# nuzakicrowd
# nvest
# nymi
# nyt
# oanda-corporation
# objectif-lune
# oceanwide
# octopusapp-inc.-(jobber)
# ode-technologies
# okanii
# omega-ats
# omers-ventures
# omnego
# omnigate-systems
# omniware-solutions
# oneledger
# onirade-inc.
# ontab
# open-avenue
# opendime
# operant.ai
# operenzy
# ophelia
# opta
# optimize-capital-markets
# optrack
# oro-services-inc
# otonom-solution
# overbond
# ownest-financial
# pagamus
# panache-ventures
# passiv
# paybright
# paybyphone
# paycase
# paycloud
# paydirt
# payexpresse
# payfare
# payfirma
# payment-rails
# payment-source
# paymentevolution
# paymentpin
# payments-canada
# paymotion
# paymytuition
# paysafe-group
# payshot
# paystation
# paystone-(zomaron)
# paytm-labs
# payup-jack
# payvida
# pbh-canada
# peach-life
# peer-ledger
# peerfunder
# perfiqt
# pets-plus-us
# phaze
# piggy-the-bank
# pivotal-payments
# playpay
# plentti
# pleo
# plooto
# plurilock
# policy-works
# polymath-network
# portag3-ventures
# pos-solutions
# posconnect-inc.
# positive-inc
# potcoin
# presto
# pricemetrix
# procurify
# progressa
# projexity
# pronavigator
# prophix-software
# psigate
# publaunch
# pungle
# purefacts
# purpose-investments-inc.
# purview
# q4
# qicsend
# qohash
# quadfi
# quandl-inc.
# quantreex
# quber
# questica
# questrade
# quote-kong-ltd
# ratehub
# ratelab
# rates.ca
# ready
# real-matters
# real-ventures
# realstarter
# recordtrust
# red-cloud-klondike-strike
# redpine-music
# refresh-financial
# reitium
# rel8ed.to
# reliablyme
# remitr
# rentmoola
# repay
# responsive
# rhino-ventures
# round-13-capital
# rta-corp
# rtrade-technologies-ltd.
# rubikloud
# running-alpha
# salt-edge
# sarakinov-consulting-inc.
# saveforward
# savvyy
# scaleup-ventures
# sebright-capital
# secondarylink
# secunik
# secure-digital-markets
# securefact
# securekey-technologies-inc.
# seeds-of-change
# senomix
# sensibill
# senso.ai
# shake-pay
# sharealpha
# shield-crypto-systems-inc
# sigone-capital
# silqe
# simplepay
# simpletax
# simply-invoice
# singlekey
# slickpie
# smallchangefund
# smart-money-invest
# smarter-loans
# smile.io
# smooth-commerce
# snap-financial-group
# snap-projections
# snappay
# softtarget
# sonnet
# soundpays
# sparcblock
# sparkrock
# speedy-cash
# splitpea
# sprout-app
# sqirl-capital
# square-one-insurance-services
# squares-union
# stack
# stock-target-advisor
# stock-trading-academy
# stockpools
# stockrender
# stradigi-ai
# streamscan
# street-contxt
# studiouspass
# sumo
# surebooks-business-services
# suretap-wallet
# swiggle
# symbility-solutions
# symend
# t360-payment-solutions
# tab
# tachvault
# tantelo
# taptrack
# techtrex
# telostouch
# telpay
# the-friendly-financial-coach
# the-funding-portal
# the-jersey-company-inc.
# the-reformulary-group
# theuptrend
# thinking-capital
# thrinacia
# ticksmith-corp.
# ticktrade
# tiptap-pay
# tokenfunder
# touchbistro
# tps-software
# traderific
# trading-central
# trippeo
# true-north-payments
# trulioo
# tuque
# u.cash
# ucollect
# unchained-entrepreneur
# uncharted
# univeris
# upa-invoice
# uremit
# urloan
# vacation-fund
# vanbex
# varro-technologies
# vaultcircle
# vena-solutions
# venbridge
# versabank
# versapay
# vested
# vicuco
# viewpoint-ai-inc.
# vigilantcs
# vio-commerce
# virgocx
# virtual-claims-adjuster
# virtual-next
# viviplan
# vohcom
# voleo,-inc.
# vopay
# vouchr
# vtacpayroll
# wagepoint
# wave-accounting
# waypay
# wealthbar
# wealthica
# wealthscope
# wealthtab
# weather-telematics
# weifund
# white-star-capital
# whitecap-venture-partners
# windward-software
# wip-software
# worklinks-inc.
# xen-accounting
# yaletown-ventures
# yoyomolo
# yupp
# zafin
# zag-bank
# zayzoon
# zensurance
# zeroone.ai
# zhippit
# zipsure
# zoompass
# zoompesa-systems-technology

# %%
# Empty lists to store values of interest (industry sector, number of employees, incorporation year, city, and province)
indSect = []
numEm = []
incYr = []
city = []
prov = []

# For each company
for i in range(len(co)):
    
    # Visit each page
    url = "https://fintechcanada.io/listing/{}".format(co[i])
    driver.get(url)
    
    # Find the Industry sector
    indSect_element = driver.find_elements_by_xpath('/html/body/div[1]/div/div[3]/section[1]/div/div/div[1]/div/div[2]/div/div[2]/p[2]')

    # If it exists, add the text to indSect
    if indSect_element:
        indSect.append(indSect_element[0].text)
    else:
        indSect.append("")
    
    # Find the number of employees
    numEm_element = driver.find_elements_by_xpath('/html/body/div[1]/div/div[3]/section[1]/div/div/div[2]/div/div[2]/div/div[2]/p[2]')
    
    # If it exists, add the text to numEm
    if numEm_element:
        numEm.append(numEm_element[0].text)
    
    # Find the incorporation year
    incYr_element = driver.find_elements_by_xpath('/html/body/div[1]/div/div[3]/section[1]/div/div/div[1]/div/div[3]/div/div[2]/p[2]')

    # If it exists, add the text to incYr
    if incYr_element:
        incYr.append(incYr_element[0].text)
    else:
        incYr.append("")
    
    # Find the city
    city_element = driver.find_elements_by_xpath('/html/body/div[1]/div/div[3]/section[1]/div/div/div[2]/div/div[1]/div/div[2]/ul/li[1]/div[2]/p')
    
    # If it exists, add the text to city
    if city_element:
        city.append(city_element[0].text)
    else:
        city.append("")
    
    # Find the province
    prov_element = driver.find_elements_by_xpath('/html/body/div[1]/div/div[3]/section[1]/div/div/div[2]/div/div[1]/div/div[2]/ul/li[2]/div[2]/p')
    
    # If it exists, add the text to prov
    if prov_element:
        prov.append(prov_element[0].text)
    else:
        prov.append("")

# Check length of each list
print(len(indSect))
print(len(incYr))
print(len(numEm))
print(len(city))
print(len(prov))
# Out:
# 930
# 930
# 878
# 930
# 930

# %%
# Convert the information collected to a data frame
df = pd.DataFrame(list(zip(coNames, city, prov, incYr, numEm, indSect)), 
                  columns=["Company", "City", "Province", "Incorporation Year", "Number of Employees", "Industry Sector"])

# Display
df
# Out:
#                     Company        City          Province Incorporation Year  \
# 0                Accesswire     Toronto           Ontario               2008
# 1      Consilium Crypto Inc     Toronto           Ontario
# 2               Exponential     Toronto           Ontario               2016
# 3                FrontFundr     Toronto           Ontario
# 4                  FundRazr   Vancouver  British Columbia
# ..                      ...         ...               ...                ...
# 873                  U.CASH     Toronto           Ontario               2015
# 874                Ucollect     Markham           Ontario               2014
# 875  Unchained Entrepreneur  St. Albert           Alberta               2017
# 876               Uncharted     Toronto           Ontario               2001
# 877                Univeris     Toronto           Ontario               1996
#
#     Number of Employees                               Industry Sector
# 0                 11-50                                Other Services
# 1
# 2               11 - 50
# 3
# 4
# ..                  ...                                           ...
# 873                      Blockchain / Digital Assets / Cryptocurrency
# 874              1 - 10                          Finance / Accounting
# 875             11 - 50                          Finance / Accounting
# 876                      Digital Banking / Analytics / Infrastructure
# 877             11 - 50            Wealthtech / Alternative Investing
#
# [878 rows x 6 columns]

# %%
# Write to csv
df.to_csv(r'FintechInfo.csv', index=False)

# %%
df2 = pd.DataFrame(list(zip(coNames, city, prov, incYr, indSect)), 
                  columns=["Company", "City", "Province", "Incorporation Year", "Industry Sector"])

df2
# Out:
#                            Company       City          Province  \
# 0                       Accesswire    Toronto           Ontario
# 1             Consilium Crypto Inc    Toronto           Ontario
# 2                      Exponential    Toronto           Ontario
# 3                       FrontFundr    Toronto           Ontario
# 4                         FundRazr  Vancouver  British Columbia
# ..                             ...        ...               ...
# 925                     zeroone.ai    Toronto           Ontario
# 926                        Zhippit    Toronto           Ontario
# 927                        ZipSure  Dartmouth       Nova Scotia
# 928                       Zoompass    Toronto           Ontario
# 929  ZOOMPesa Systems & Technology     Canada
#
#     Incorporation Year                        Industry Sector
# 0                 2008                         Other Services
# 1
# 2                 2016
# 3
# 4
# ..                 ...                                    ...
# 925               2018  Capital Markets / DeFi / Crowdfinance
# 926               2014         Payments / Transfers / Rewards
# 927               2011
# 928               2004         Payments / Transfers / Rewards
# 929
#
# [930 rows x 5 columns]

# %%
df2.to_csv(r'FinTechInformation.csv', index=False)
